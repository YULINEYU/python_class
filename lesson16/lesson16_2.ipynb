# %% [markdown]
# https://www.perplexity.ai/search/8906abee-eea5-4924-8e07-f2f2029af740

# %%
import numpy as np
import pandas as pd
#建立50位學生5個分數,每個分數的值是50~100之間的隨機整數
scores = np.random.randint(50,101,size=(50, 5))
score_pd = pd.DataFrame(scores,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index=[f'學生{index}' for index in range(1,51)])
type(score_pd.index)
score_pd.columns.name = '科目'
score_pd.index.name = '學號'
sum_series = np.sum(score_pd, axis=1)
mean_series = score_pd.mean(axis=1)
score_pd['總分'] = sum_series
score_pd['平均'] = mean_series

# %%
sorted_pd = score_pd.sort_values(by='總分',ascending=False)
rand_series = sorted_pd['總分'].rank(ascending=False,method='min')
sorted_pd['名次'] = rand_series

# %%
sorted_pd
# Out:
# 科目     國文  英文   數學  地理   歷史   總分    平均    名次
# 學號
# 學生16   80  91   92  97   95  455  91.0   1.0
# 學生1    95  91   90  80   89  445  89.0   2.0
# 學生43   72  87  100  89   76  424  84.8   3.0
# 學生29   89  89   65  91   88  422  84.4   4.0
# 學生49   78  95   58  91   98  420  84.0   5.0
# 學生9    95  67   70  87   96  415  83.0   6.0
# 學生23   80  96   85  68   86  415  83.0   6.0
# 學生5    70  87   56  99  100  412  82.4   8.0
# 學生46   81  89   97  51   93  411  82.2   9.0
# 學生37   81  88   81  87   73  410  82.0  10.0
# 學生8    67  87   91  76   82  403  80.6  11.0
# 學生30   92  75   78  64   93  402  80.4  12.0
# 學生31   62  65   88  96   90  401  80.2  13.0
# 學生50   88  63   91  95   64  401  80.2  13.0
# 學生44   89  57   97  65   92  400  80.0  15.0
# 學生7    90  87   50  87   86  400  80.0  15.0
# 學生15   56  95   98  56   93  398  79.6  17.0
# 學生12   82  81   84  72   77  396  79.2  18.0
# 學生21   84  80   69  63   98  394  78.8  19.0
# 學生27   88  81   85  61   76  391  78.2  20.0
# 學生42   93  92   99  51   55  390  78.0  21.0
# 學生39   99  98   51  74   67  389  77.8  22.0
# 學生18   94  88   60  74   66  382  76.4  23.0
# 學生32  100  87   77  51   67  382  76.4  23.0
# 學生6    94  78   70  66   72  380  76.0  25.0
# 學生47   93  81   61  85   58  378  75.6  26.0
# 學生13   54  95   86  84   59  378  75.6  26.0
# 學生24   53  66   77  85   92  373  74.6  28.0
# 學生26   57  70   85  91   68  371  74.2  29.0
# 學生28   81  98   64  74   54  371  74.2  29.0
# 學生20   81  81   62  90   55  369  73.8  31.0
# 學生41   51  99   58  78   82  368  73.6  32.0
# 學生40   52  97   75  51   88  363  72.6  33.0
# 學生33   64  72   97  54   71  358  71.6  34.0
# 學生35   82  78   70  50   77  357  71.4  35.0
# 學生11   57  57   59  84   96  353  70.6  36.0
# 學生34   67  63   68  97   57  352  70.4  37.0
# 學生10   94  53   54  79   71  351  70.2  38.0
# 學生14   63  64   95  64   65  351  70.2  38.0
# 學生38   62  83   65  63   76  349  69.8  40.0
# 學生48   77  50   56  87   79  349  69.8  40.0
# 學生2    77  58   74  61   75  345  69.0  42.0
# 學生25   81  60   63  60   78  342  68.4  43.0
# 學生22   62  50   64  90   74  340  68.0  44.0
# 學生19   72  60   62  76   70  340  68.0  44.0
# 學生17   86  65   72  66   51  340  68.0  44.0
# 學生45   74  57   65  53   82  331  66.2  47.0
# 學生4    57  65   58  78   68  326  65.2  48.0
# 學生3    66  65   59  56   54  300  60.0  49.0
# 學生36   51  57   56  52   62  278  55.6  50.0
